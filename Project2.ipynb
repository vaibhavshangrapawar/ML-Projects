# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\ML Project\placement.csv")
data
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
data.shape
# Out:
# (200, 2)

# %%
plt.scatter(data['cgpa'],data['package'])
plt.xlabel('cgpa')
plt.ylabel('package(LPA)')
# Out:
# Text(0, 0.5, 'package(LPA)')

# %%
x=data.iloc[:,0:1]
y=data.iloc[:,-1]
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
M=LinearRegression()
M.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(data['cgpa'],data['package'])
plt.plot(x_train,M.predict(x_train),color='red')
plt.xlabel('cgpa')
plt.ylabel('pakage')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18796\2853765462.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
